# %%
import pandas as pd

# Get the keys for the empty rows
df = pd.read_csv('qrv.csv', encoding="ISO-8859-1")
print(df.iloc[26248], "\n", df.iloc[26249])

#Use Battery LMAO Module, but that doesn't seem relevant
# Out:
# Level                                                                   7
# Key                     EV00004608-SY00005795-SB00003830-GP00009740-SB...
# System                                                       BATTERY PACK
# Subsystem                                                         BATTERY
# Part Number                                                    PT00097965
# Part Title                                       Physical Product09281008
# Parent                                                         GP00004451
# Responsible Engineer                                           Mickey Hua
# Procurement Code                                                      NaN
# Sub Component Code                                                    NaN
# Variant                       QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# Name: 26248, dtype: object
#  Level                                                                   7
# ...

# %%
# First check if the engineer appears anywhere else
engineers = df['Responsible Engineer']
for e in engineers:
    if "Mickey Hua" in e:
        print(e)
# Out:
# Mickey Hua
# Mickey Hua

# %%
#"GP00004451"
# Just look for the part of the parent
x = df[df["Part Number"] == "GP00004451"]
# Out:
#        Level                                                Key        System  \
# 26184      6  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
#
#       Subsystem Part Number        Part Title      Parent  \
# 26184   BATTERY  GP00004451  Bolt 5MM Type A1  SB00010277
#
#       Responsible Engineer Procurement Code Sub Component Code  \
# 26184          Donkey Kong          Phantom                NaN
#
#                                            Variant
# 26184  QRV: Battery{LMAO 5 Module,LMAO 190 Module}

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a793762d-7273-44b0-a0bd-a26f44b8f6a3' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
