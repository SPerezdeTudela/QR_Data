# %%
import pandas as pd

df = pd.read_csv('qrv.csv', encoding="ISO-8859-1")

# Display the DataFrame
print(df.columns)

df
# Out:
# Index(['Level', 'Key', 'System', 'Subsystem', 'Part Number', 'Part Title',
#        'Parent', 'Responsible Engineer', 'Procurement Code',
#        'Sub Component Code', 'Variant'],
#       dtype='object')
#        Level                                                Key        System  \
# 0          1                                         EV00004608          BODY
# 1          2                              EV00004608-SY00002272          BODY
# 2          3                   EV00004608-SY00002272-SB00007686          BODY
# 3          4        EV00004608-SY00002272-SB00007686-GP00005889          BODY
# 4          5  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# ...      ...                                                ...           ...
# 69380      9  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69381      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69382      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69383      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69384      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
#
#        Subsystem  Part Number                     Part Title      Parent  \
# 0            NaN   EV00004608                     QR Vehicle         NaN
# 1            NaN   SY00002272                           BODY  EV00004608
# 2      STRUCTURE   SB00007686                      STRUCTURE  SY00002272
# 3      STRUCTURE   GP00005889                          SEALS  SB00007686
# 4      STRUCTURE  CAY00010323             BODY STORE SEALANT  GP00005889
# ...          ...          ...                            ...         ...
# 69380    BATTERY   SC00013805                      Foam 607P  PT01597040
# 69381    BATTERY   PT01759813  TOUCH COVER; NEGATIVE - LARGE  PT01759805
# 69382    BATTERY   PT01759815  TOUCH COVER; POSITIVE - LARGE  PT01759805
# 69383    BATTERY   PT00052426              SHEAR WALL; 3BOLT  PT01759805
# 69384    BATTERY   PT00052426              SHEAR WALL; 3BOLT  PT01759805
#
#       Responsible Engineer Procurement Code Sub Component Code  \
# 0             Rachel Green          Phantom                NaN
# 1             Rachel Green          Phantom                NaN
# 2             Rachel Green          Phantom                NaN
# 3             Rachel Green          Phantom                NaN
# 4            Pheobe Buffay          Phantom                NaN
# ...                    ...              ...                ...
# 69380       Duke Weaselton              Buy                NaN
# 69381              Swagman             Make                NaN
# 69382              Swagman              Buy                NaN
# 69383           Judy Hopps              Buy                NaN
# 69384           Judy Hopps              Buy                NaN
#
#                                            Variant
# 0                             QRV: Car Type{Venti}
# 1                             QRV: Car Type{Venti}
# 2                             QRV: Car Type{Venti}
# 3                             QRV: Car Type{Venti}
# 4                             QRV: Car Type{Venti}
# ...                                            ...
# 69380  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69381  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69382  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69383  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69384  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
#
# [69385 rows x 11 columns]

# %%
filtered_rows = []
count = 0
for _, row in df.iterrows():
    part_number = row['Part Number']
    parent_part = row['Parent']
    
    # Check if the parent part has a "Procurement Code" of "Buy" and "Subcomponent Code" is NaN
    parent_row = df[df['Part Number'] == parent_part]
    
    if count % 1000 == 0:
        print(count)
        
        
    if not parent_row.empty:
        parent_procurement_code = parent_row.iloc[0]['Procurement Code']        
        if parent_procurement_code == 'Make' or parent_procurement_code == "Phantom":
            filtered_rows.append(row)
    
    count = count + 1

# Create a new DataFrame from the filtered rows
filtered_df = pd.DataFrame(filtered_rows, columns=df.columns)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000

# %%
filtered_df
# Out:
#        Level                                                Key        System  \
# 1          2                              EV00004608-SY00002272          BODY
# 2          3                   EV00004608-SY00002272-SB00007686          BODY
# 3          4        EV00004608-SY00002272-SB00007686-GP00005889          BODY
# 4          5  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 5          6  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# ...      ...                                                ...           ...
# 69380      9  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69381      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69382      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69383      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69384      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
#
#        Subsystem  Part Number                     Part Title       Parent  \
# 1            NaN   SY00002272                           BODY   EV00004608
# 2      STRUCTURE   SB00007686                      STRUCTURE   SY00002272
# 3      STRUCTURE   GP00005889                          SEALS   SB00007686
# 4      STRUCTURE  CAY00010323             BODY STORE SEALANT   GP00005889
# 5      STRUCTURE   PT00015718         SEALER - UNDERBODY CAB  CAY00010323
# ...          ...          ...                            ...          ...
# 69380    BATTERY   SC00013805                      Foam 607P   PT01597040
# 69381    BATTERY   PT01759813  TOUCH COVER; NEGATIVE - LARGE   PT01759805
# 69382    BATTERY   PT01759815  TOUCH COVER; POSITIVE - LARGE   PT01759805
# 69383    BATTERY   PT00052426              SHEAR WALL; 3BOLT   PT01759805
# 69384    BATTERY   PT00052426              SHEAR WALL; 3BOLT   PT01759805
#
#       Responsible Engineer Procurement Code Sub Component Code  \
# 1             Rachel Green          Phantom                NaN
# 2             Rachel Green          Phantom                NaN
# 3             Rachel Green          Phantom                NaN
# 4            Pheobe Buffay          Phantom                NaN
# 5            Pheobe Buffay          Phantom                NaN
# ...                    ...              ...                ...
# 69380       Duke Weaselton              Buy                NaN
# 69381              Swagman             Make                NaN
# 69382              Swagman              Buy                NaN
# 69383           Judy Hopps              Buy                NaN
# 69384           Judy Hopps              Buy                NaN
#
#                                            Variant
# 1                             QRV: Car Type{Venti}
# 2                             QRV: Car Type{Venti}
# 3                             QRV: Car Type{Venti}
# 4                             QRV: Car Type{Venti}
# 5                             QRV: Car Type{Venti}
# ...                                            ...
# 69380  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69381  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69382  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69383  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69384  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
#
# [56974 rows x 11 columns]

# %%
wrong_rows = []

for _, row in filtered_df.iterrows():
    procurement_code = row['Procurement Code']
    subcomponent_code = row['Sub Component Code']
    
    if procurement_code == 'Buy' and (not pd.isna(subcomponent_code)):
        wrong_rows.append(row)
    
wrong_rows_df = pd.DataFrame(wrong_rows, columns=df.columns)

wrong_rows_df
# Out:
#        Level                                                Key        System  \
# 556        7  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 1142       7  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 2299       7  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 2671       7  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 2857       8  EV00004608-SY00002272-SB00007686-GP00010894-CA...          BODY
# ...      ...                                                ...           ...
# 56199      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 57210      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 58222      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 59234      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 60246      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
#
#        Subsystem Part Number                 Part Title      Parent  \
# 556    STRUCTURE  PT00025488      BODY SIDE ADHESIVE LH  PT00022098
# 1142   STRUCTURE  PT00091308   TAPE CHEEZE 3 x 23 x 116  PT00090886
# 2299   STRUCTURE  PT00091308   TAPE CHEEZE 3 x 23 x 116  PT00090886
# 2671   STRUCTURE  PT00091308   TAPE CHEEZE 3 x 23 x 116  PT00090886
# 2857   STRUCTURE  PT00019920    CORNER RADAR BRACKET-RH  PT00020314
# ...          ...         ...                        ...         ...
# 56199    BATTERY  PT01709810      TOUCH COVER; POSITIVE  PT01550426
# 57210    BATTERY  PT01709810      TOUCH COVER; POSITIVE  PT01550426
# 58222    BATTERY  PT01709810      TOUCH COVER; POSITIVE  PT01550426
# 59234    BATTERY  PT01709810      TOUCH COVER; POSITIVE  PT01550426
# 60246    BATTERY  PT01709810      TOUCH COVER; POSITIVE  PT01550426
#
#       Responsible Engineer Procurement Code Sub Component Code  \
# 556          Monica Geller              Buy        SupplierBuy
# 1142         Pheobe Buffay              Buy        DirectedBuy
# 2299         Pheobe Buffay              Buy        DirectedBuy
# 2671         Pheobe Buffay              Buy        DirectedBuy
# 2857         Pheobe Buffay              Buy        SupplierBuy
# ...                    ...              ...                ...
# 56199            Pinocchio              Buy        DirectedBuy
# 57210            Pinocchio              Buy        DirectedBuy
# 58222            Pinocchio              Buy        DirectedBuy
# 59234            Pinocchio              Buy        DirectedBuy
# 60246            Pinocchio              Buy        DirectedBuy
#
#                                             Variant
# 556                            QRV: Car Type{Venti}
# 1142                           QRV: Car Type{Venti}
# 2299   QRV: Car Type{Grande} AND Handed Drive{LHD }
# 2671   QRV: Car Type{Grande} AND Handed Drive{RHD }
# 2857                      QRV: Car Type{Venti,Tall}
# ...                                             ...
# 56199   QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 57210   QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 58222   QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 59234   QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 60246   QRV: Battery{LMAO 5 Module,LMAO 190 Module}
#
# [699 rows x 11 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Group by 'systems' and 'subsystem' and count
grouped = wrong_rows_df.groupby(['System', 'Subsystem']).size().unstack(fill_value=0)

# Plot stacked bar chart
grouped.plot(kind='bar', stacked=True, figsize=(10, 6))

plt.xlabel('Systems')
plt.ylabel('Count')
plt.title('Stacked Column Chart')
plt.legend(title='Subsystem', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
right_rows = []

for _, row in filtered_df.iterrows():
    procurement_code = row['Procurement Code']
    subcomponent_code = row['Sub Component Code']
    
    if procurement_code == 'Buy' and pd.isna(subcomponent_code):
        right_rows.append(row)
    elif((procurement_code == 'Phantom' or procurement_code == 'Make') and not procurement_code == 'Buy'):
        right_rows.append(row)
    
right_rows_df = pd.DataFrame(right_rows, columns=df.columns)

right_rows_df
# Out:
#        Level                                                Key        System  \
# 1          2                              EV00004608-SY00002272          BODY
# 2          3                   EV00004608-SY00002272-SB00007686          BODY
# 3          4        EV00004608-SY00002272-SB00007686-GP00005889          BODY
# 4          5  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 5          6  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# ...      ...                                                ...           ...
# 69380      9  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69381      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69382      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69383      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69384      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
#
#        Subsystem  Part Number                     Part Title       Parent  \
# 1            NaN   SY00002272                           BODY   EV00004608
# 2      STRUCTURE   SB00007686                      STRUCTURE   SY00002272
# 3      STRUCTURE   GP00005889                          SEALS   SB00007686
# 4      STRUCTURE  CAY00010323             BODY STORE SEALANT   GP00005889
# 5      STRUCTURE   PT00015718         SEALER - UNDERBODY CAB  CAY00010323
# ...          ...          ...                            ...          ...
# 69380    BATTERY   SC00013805                      Foam 607P   PT01597040
# 69381    BATTERY   PT01759813  TOUCH COVER; NEGATIVE - LARGE   PT01759805
# 69382    BATTERY   PT01759815  TOUCH COVER; POSITIVE - LARGE   PT01759805
# 69383    BATTERY   PT00052426              SHEAR WALL; 3BOLT   PT01759805
# 69384    BATTERY   PT00052426              SHEAR WALL; 3BOLT   PT01759805
#
#       Responsible Engineer Procurement Code Sub Component Code  \
# 1             Rachel Green          Phantom                NaN
# 2             Rachel Green          Phantom                NaN
# 3             Rachel Green          Phantom                NaN
# 4            Pheobe Buffay          Phantom                NaN
# 5            Pheobe Buffay          Phantom                NaN
# ...                    ...              ...                ...
# 69380       Duke Weaselton              Buy                NaN
# 69381              Swagman             Make                NaN
# 69382              Swagman              Buy                NaN
# 69383           Judy Hopps              Buy                NaN
# 69384           Judy Hopps              Buy                NaN
#
#                                            Variant
# 1                             QRV: Car Type{Venti}
# 2                             QRV: Car Type{Venti}
# 3                             QRV: Car Type{Venti}
# 4                             QRV: Car Type{Venti}
# 5                             QRV: Car Type{Venti}
# ...                                            ...
# 69380  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69381  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69382  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69383  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69384  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
#
# [56273 rows x 11 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Group by 'systems' and 'subsystem' and count
grouped = right_rows_df.groupby(['System', 'Subsystem']).size().unstack(fill_value=0)

# Plot stacked bar chart
grouped.plot(kind='bar', stacked=True, figsize=(10, 6))

plt.xlabel('Systems')
plt.ylabel('Count')
plt.title('Stacked Column Chart')
plt.legend(title='Subsystem', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
# of the 3299 rows that fit this category, 2450 are correct


# sort by level, insert into tree, 


# find if some rows don't have existing parents


import pandas as pd

# Sample DataFrame

# Print counts of unique values in 'systems' column
wrong = (wrong_rows_df['Subsystem'].value_counts())

# %%
import pandas as pd

# Sample DataFrame

# Print counts of unique values in 'systems' column
right = (right_rows_df['Subsystem'].value_counts())

# %%
combined_series = wrong.add(right, fill_value=0).astype(int)

division_series = right.divide(combined_series, fill_value=0)

# Replace NaN values with 0
division_series = division_series.fillna(0)

# Print the division result
print(division_series)
# Out:
# ACOUSTIC ALERTS                 0.952381
# AMAZING ELECTRONICS             1.000000
# AMAZON ELECTRONICS              1.000000
# ANTENNA                         0.973684
# AUDIO SUBSYSTEM                 1.000000
# AUTOPILOT HARDWARE              1.000000
# AUTOPILOT SOFTWARE              1.000000
# AUX POWER                       1.000000
# AUXILIARY POWER SUPPLY          1.000000
# BATTERY                         0.994765
# BRAKES                          0.992593
# CLOSURES                        0.972644
# COCKPIT                         0.987988
# CRASH DETECTION                 1.000000
# CRFM                            0.904762
# DISPLAYS                        1.000000
# DOORS                           0.955556
# ENERGY MANAGEMENT               1.000000
# ENVIRONMENTAL CONTROL           1.000000
# ESS LOOP                        1.000000
# EXTERIOR                        0.887570
# FANS                            1.000000
# FIELD OF VISION                 1.000000
# FLOOR                           1.000000
# FLUIDS                          1.000000
# HARDWARE                        1.000000
# HARDWARE - LOW VOLTAGE          0.992701
# HARNESSES                       1.000000
# HV DISTRIBUTION                 1.000000
# HVAC                            0.931034
# INPUT SWITCHES                  1.000000
# INVERTER                        1.000000
# JETPACK                         1.000000
# MOLECULES                       1.000000
# PARKING                         1.000000
# PHOTOSYNTHESIS                  1.000000
# POWER DISTRIBUTION              1.000000
# POWER DISTRIBUTION SUBSYSTEM    0.927215
# PROPULSION - FRT                0.871658
# REFRIGERATION LOOP              0.969697
# RESTRAINTS                      0.918919
# SAFETY                          1.000000
# SEATS                           0.723684
# SENSORS                         0.857143
# SENSORS SUBSYSTEM               0.666667
# STATUS MONITORING & SENSING     1.000000
# STEERING                        0.978022
# STRUCTURE                       0.987086
# SUSPENSION                      0.960938
# THERMAL CONTROL                 1.000000
# TRACTION LOOP                   0.991736
# TRIM                            0.951477
# USER INPUT SWITCHES             0.871795
# VEHICLE ACCESS                  0.607143
# WHEELS AND TIRES                1.000000
# Name: Subsystem, dtype: float64

# %%
sorted_series = division_series.sort_values(ascending=False)

# Print the sorted Series
print(sorted_series)
# Out:
# HARNESSES                       1.000000
# INVERTER                        1.000000
# FIELD OF VISION                 1.000000
# FLOOR                           1.000000
# FLUIDS                          1.000000
# HARDWARE                        1.000000
# AMAZING ELECTRONICS             1.000000
# HV DISTRIBUTION                 1.000000
# INPUT SWITCHES                  1.000000
# JETPACK                         1.000000
# ESS LOOP                        1.000000
# MOLECULES                       1.000000
# PARKING                         1.000000
# PHOTOSYNTHESIS                  1.000000
# POWER DISTRIBUTION              1.000000
# SAFETY                          1.000000
# STATUS MONITORING & SENSING     1.000000
# THERMAL CONTROL                 1.000000
# FANS                            1.000000
# WHEELS AND TIRES                1.000000
# AUTOPILOT HARDWARE              1.000000
# ENERGY MANAGEMENT               1.000000
# DISPLAYS                        1.000000
# AUDIO SUBSYSTEM                 1.000000
# CRASH DETECTION                 1.000000
# AMAZON ELECTRONICS              1.000000
# ENVIRONMENTAL CONTROL           1.000000
# AUXILIARY POWER SUPPLY          1.000000
# AUX POWER                       1.000000
# AUTOPILOT SOFTWARE              1.000000
# BATTERY                         0.994765
# HARDWARE - LOW VOLTAGE          0.992701
# BRAKES                          0.992593
# TRACTION LOOP                   0.991736
# COCKPIT                         0.987988
# STRUCTURE                       0.987086
# STEERING                        0.978022
# ANTENNA                         0.973684
# CLOSURES                        0.972644
# REFRIGERATION LOOP              0.969697
# SUSPENSION                      0.960938
# DOORS                           0.955556
# ACOUSTIC ALERTS                 0.952381
# TRIM                            0.951477
# HVAC                            0.931034
# POWER DISTRIBUTION SUBSYSTEM    0.927215
# RESTRAINTS                      0.918919
# CRFM                            0.904762
# EXTERIOR                        0.887570
# USER INPUT SWITCHES             0.871795
# PROPULSION - FRT                0.871658
# SENSORS                         0.857143
# SEATS                           0.723684
# SENSORS SUBSYSTEM               0.666667
# VEHICLE ACCESS                  0.607143
# Name: Subsystem, dtype: float64

# %%
import matplotlib.pyplot as plt

# Sort the division result by values in descending order
sorted_series = division_series.sort_values(ascending=False)

# Create the bar plot
plt.figure(figsize=(12, 8))
sorted_series.plot(kind='bar', color='skyblue')
plt.xlabel('Subsystem')
plt.ylabel('Division Result')
plt.title('Procurement Code Health By Subsystem')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
words_to_search = ['Tall', 'tall']
column_to_search = 'Variant'

# Create a pattern to search for multiple words
pattern = '|'.join(words_to_search)

# Count occurrences of the words in the "Description" column
count = wrong_rows_df[column_to_search].str.contains(pattern, case=False, na=False).sum()


print(count)

words_to_search = ['Grande', 'grande']
column_to_search = 'Variant'

# Create a pattern to search for multiple words
pattern = '|'.join(words_to_search)

# Count occurrences of the words in the "Description" column
count = wrong_rows_df[column_to_search].str.contains(pattern, case=False, na=False).sum()


print(count)

words_to_search = ['Venti', 'venti']
column_to_search = 'Variant'

# Create a pattern to search for multiple words
pattern = '|'.join(words_to_search)

# Count occurrences of the words in the "Description" column
count = wrong_rows_df[column_to_search].str.contains(pattern, case=False, na=False).sum()


print(count)
# Out:
# 146
# 241
# 159

# %%
words_to_search = ['Tall', 'tall']
column_to_search = 'Variant'

# Create a pattern to search for multiple words
pattern = '|'.join(words_to_search)

# Count occurrences of the words in the "Description" column
count = filtered_df[column_to_search].str.contains(pattern, case=False, na=False).sum()


print(count)

words_to_search = ['Grande', 'grande']
column_to_search = 'Variant'

# Create a pattern to search for multiple words
pattern = '|'.join(words_to_search)

# Count occurrences of the words in the "Description" column
count = filtered_df[column_to_search].str.contains(pattern, case=False, na=False).sum()


print(count)

words_to_search = ['Venti', 'venti']
column_to_search = 'Variant'

# Create a pattern to search for multiple words
pattern = '|'.join(words_to_search)

# Count occurrences of the words in the "Description" column
count = filtered_df[column_to_search].str.contains(pattern, case=False, na=False).sum()


print(count)
# Out:
# 3397
# 6750
# 5192

# %%
# of the 3299 rows that fit this category, 2450 are correct


# sort by level, insert into tree, 


# find if some rows don't have existing parents


import pandas as pd

# Sample DataFrame

# Print counts of unique values in 'systems' column
total = filtered_df['Level'].value_counts().sort_index()

import pandas as pd

# Sample DataFrame

# Print counts of unique values in 'systems' column
wrong = wrong_rows_df['Level'].value_counts().sort_index()

import pandas as pd

# Sample DataFrame

# Print counts of unique values in 'systems' column
right = right_rows_df['Level'].value_counts()

import pandas as pd

# Sample DataFrame

# Print counts of unique values in 'systems' column
wrong = wrong_rows_df['Level'].value_counts()

combined_series = wrong.add(right, fill_value=0).astype(int)

division_series = right.divide(combined_series, fill_value=0)

# Replace NaN values with 0
division_series = division_series.fillna(0)

# Print the division result

sorted_series = division_series

# Print the sorted Series

import matplotlib.pyplot as plt

# Sort the division result by values in descending order
sorted_series = division_series

# Create the bar plot
plt.figure(figsize=(12, 8))
sorted_series.plot(kind='bar', color='skyblue')
plt.xlabel('Level')
plt.ylabel('Division Result')
plt.title('Procurement Code Health By Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
