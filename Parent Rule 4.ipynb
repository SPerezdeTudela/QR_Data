# %%
import pandas as pd

df = pd.read_csv('qrv.csv', encoding="ISO-8859-1")

# Display the DataFrame
print(df.columns)

df
# Out:
# Index(['Level', 'Key', 'System', 'Subsystem', 'Part Number', 'Part Title',
#        'Parent', 'Responsible Engineer', 'Procurement Code',
#        'Sub Component Code', 'Variant'],
#       dtype='object')
#        Level                                                Key        System  \
# 0          1                                         EV00004608          BODY
# 1          2                              EV00004608-SY00002272          BODY
# 2          3                   EV00004608-SY00002272-SB00007686          BODY
# 3          4        EV00004608-SY00002272-SB00007686-GP00005889          BODY
# 4          5  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# ...      ...                                                ...           ...
# 69380      9  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69381      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69382      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69383      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69384      8  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
#
#        Subsystem  Part Number                     Part Title      Parent  \
# 0            NaN   EV00004608                     QR Vehicle         NaN
# 1            NaN   SY00002272                           BODY  EV00004608
# 2      STRUCTURE   SB00007686                      STRUCTURE  SY00002272
# 3      STRUCTURE   GP00005889                          SEALS  SB00007686
# 4      STRUCTURE  CAY00010323             BODY STORE SEALANT  GP00005889
# ...          ...          ...                            ...         ...
# 69380    BATTERY   SC00013805                      Foam 607P  PT01597040
# 69381    BATTERY   PT01759813  TOUCH COVER; NEGATIVE - LARGE  PT01759805
# 69382    BATTERY   PT01759815  TOUCH COVER; POSITIVE - LARGE  PT01759805
# 69383    BATTERY   PT00052426              SHEAR WALL; 3BOLT  PT01759805
# 69384    BATTERY   PT00052426              SHEAR WALL; 3BOLT  PT01759805
#
#       Responsible Engineer Procurement Code Sub Component Code  \
# 0             Rachel Green          Phantom                NaN
# 1             Rachel Green          Phantom                NaN
# 2             Rachel Green          Phantom                NaN
# 3             Rachel Green          Phantom                NaN
# 4            Pheobe Buffay          Phantom                NaN
# ...                    ...              ...                ...
# 69380       Duke Weaselton              Buy                NaN
# 69381              Swagman             Make                NaN
# 69382              Swagman              Buy                NaN
# 69383           Judy Hopps              Buy                NaN
# 69384           Judy Hopps              Buy                NaN
#
#                                            Variant
# 0                             QRV: Car Type{Venti}
# 1                             QRV: Car Type{Venti}
# 2                             QRV: Car Type{Venti}
# 3                             QRV: Car Type{Venti}
# 4                             QRV: Car Type{Venti}
# ...                                            ...
# 69380  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69381  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69382  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69383  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69384  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
#
# [69385 rows x 11 columns]

# %%
filtered_rows = []
count = 0
for _, row in df.iterrows():
    part_number = row['Part Number']
    parent_part = row['Parent']
    
    # Check if the parent part has a "Procurement Code" of "Buy" and "Subcomponent Code" is NaN
    parent_row = df[df['Part Number'] == parent_part]
    
    if count % 1000 == 0:
        print(count)
        
        
    if not parent_row.empty:
        parent_procurement_code = parent_row.iloc[0]['Procurement Code']
        parent_subcomponent_code = parent_row.iloc[0]['Sub Component Code']
        
        if parent_procurement_code == 'Buy' and parent_subcomponent_code == "SupplierBuy":
            filtered_rows.append(row)
    
    count = count + 1

# Create a new DataFrame from the filtered rows
filtered_df = pd.DataFrame(filtered_rows, columns=df.columns)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000

# %%
filtered_df
# Out:
#        Level                                                Key        System  \
# 557        8  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 558        8  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 559        8  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 560        8  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 561        8  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# ...      ...                                                ...           ...
# 69317     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69319     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69321     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69323     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69325     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
#
#        Subsystem Part Number          Part Title      Parent  \
# 557    STRUCTURE  SC00012821   Adhesive Type D23  PT00025488
# 558    STRUCTURE  SC00012821   Adhesive Type D23  PT00025488
# 559    STRUCTURE  SC00012821   Adhesive Type D23  PT00025488
# 560    STRUCTURE  SC00012821   Adhesive Type D23  PT00025488
# 561    STRUCTURE  SC00012821   Adhesive Type D23  PT00025488
# ...          ...         ...                 ...         ...
# 69317    BATTERY  PT00051315  Sour Patch Gummies  PT00015983
# 69319    BATTERY  PT00051311      Motorboat Tail  PT00015975
# 69321    BATTERY  PT00051315  Sour Patch Gummies  PT00015983
# 69323    BATTERY  PT00051311      Motorboat Tail  PT00015975
# 69325    BATTERY  PT00051310     Charge Port BCA  PT00015978
#
#       Responsible Engineer Procurement Code Sub Component Code  \
# 557            Ross Geller              Buy                NaN
# 558            Ross Geller              Buy                NaN
# 559            Ross Geller              Buy                NaN
# 560            Ross Geller              Buy                NaN
# 561            Ross Geller              Buy                NaN
# ...                    ...              ...                ...
# 69317      Dawn Bellwether              Buy        SupplierBuy
# 69319      Dawn Bellwether              Buy        SupplierBuy
# 69321      Dawn Bellwether              Buy        SupplierBuy
# 69323      Dawn Bellwether              Buy        SupplierBuy
# 69325           Chief Bogo              Buy        DirectedBuy
#
#                                            Variant
# 557                           QRV: Car Type{Venti}
# 558                           QRV: Car Type{Venti}
# 559                           QRV: Car Type{Venti}
# 560                           QRV: Car Type{Venti}
# 561                           QRV: Car Type{Venti}
# ...                                            ...
# 69317  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69319  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69321  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69323  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69325  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
#
# [2685 rows x 11 columns]

# %%
wrong_rows = []

for _, row in filtered_df.iterrows():
    procurement_code = row['Procurement Code']
    subcomponent_code = row['Sub Component Code']
    
    if procurement_code == 'Buy' and (not subcomponent_code == 'SupplierBuy'):
        wrong_rows.append(row)
    elif (not procurement_code == 'Phantom' and not procurement_code == "Buy"):
        wrong_rows.append(row)
    
wrong_rows_df = pd.DataFrame(wrong_rows, columns=df.columns)

wrong_rows_df
# Out:
#        Level                                                Key        System  \
# 557        8  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 558        8  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 559        8  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 560        8  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# 561        8  EV00004608-SY00002272-SB00007686-GP00005889-CA...          BODY
# ...      ...                                                ...           ...
# 68313     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 68832     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 68844     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69313     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69325     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
#
#        Subsystem Part Number         Part Title      Parent  \
# 557    STRUCTURE  SC00012821  Adhesive Type D23  PT00025488
# 558    STRUCTURE  SC00012821  Adhesive Type D23  PT00025488
# 559    STRUCTURE  SC00012821  Adhesive Type D23  PT00025488
# 560    STRUCTURE  SC00012821  Adhesive Type D23  PT00025488
# 561    STRUCTURE  SC00012821  Adhesive Type D23  PT00025488
# ...          ...         ...                ...         ...
# 68313    BATTERY  PT00051310    Charge Port BCA  PT00015978
# 68832    BATTERY  PT00051313    Friday the 13th  PT00015980
# 68844    BATTERY  PT00051310    Charge Port BCA  PT00015978
# 69313    BATTERY  PT00051313    Friday the 13th  PT00015980
# 69325    BATTERY  PT00051310    Charge Port BCA  PT00015978
#
#       Responsible Engineer Procurement Code Sub Component Code  \
# 557            Ross Geller              Buy                NaN
# 558            Ross Geller              Buy                NaN
# 559            Ross Geller              Buy                NaN
# 560            Ross Geller              Buy                NaN
# 561            Ross Geller              Buy                NaN
# ...                    ...              ...                ...
# 68313           Chief Bogo              Buy        DirectedBuy
# 68832      Dawn Bellwether             Make        SupplierBuy
# 68844           Chief Bogo              Buy        DirectedBuy
# 69313      Dawn Bellwether             Make        SupplierBuy
# 69325           Chief Bogo              Buy        DirectedBuy
#
#                                            Variant
# 557                           QRV: Car Type{Venti}
# 558                           QRV: Car Type{Venti}
# 559                           QRV: Car Type{Venti}
# 560                           QRV: Car Type{Venti}
# 561                           QRV: Car Type{Venti}
# ...                                            ...
# 68313  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 68832  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 68844  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69313  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69325  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
#
# [931 rows x 11 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Group by 'systems' and 'subsystem' and count
grouped = wrong_rows_df.groupby(['System', 'Subsystem']).size().unstack(fill_value=0)

# Plot stacked bar chart
grouped.plot(kind='bar', stacked=True, figsize=(10, 6))

plt.xlabel('Systems')
plt.ylabel('Count')
plt.title('Stacked Column Chart')
plt.legend(title='Subsystem', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
right_rows = []

for _, row in filtered_df.iterrows():
    procurement_code = row['Procurement Code']
    subcomponent_code = row['Sub Component Code']
    
    if procurement_code == 'Buy' and (subcomponent_code == 'SupplierBuy'):
        right_rows.append(row)
    elif( procurement_code == 'Phantom'):
        right_rows.append(row)
    
right_rows_df = pd.DataFrame(right_rows, columns=df.columns)

right_rows_df
# Out:
#        Level                                                Key        System  \
# 2717       8  EV00004608-SY00002272-SB00007686-GP00010894-CA...          BODY
# 2718       8  EV00004608-SY00002272-SB00007686-GP00010894-CA...          BODY
# 2720       8  EV00004608-SY00002272-SB00007686-GP00010894-CA...          BODY
# 2739       8  EV00004608-SY00002272-SB00007686-GP00010894-CA...          BODY
# 2740       8  EV00004608-SY00002272-SB00007686-GP00010894-CA...          BODY
# ...      ...                                                ...           ...
# 69315     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69317     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69319     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69321     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
# 69323     11  EV00004608-SY00005795-SB00003830-GP00009740-SB...  BATTERY PACK
#
#        Subsystem Part Number                     Part Title      Parent  \
# 2717   STRUCTURE  PT00053563  REINF - CRUSH CAN ; UPR ; QRV  PT00075766
# 2718   STRUCTURE  PT00084185              FRT_CC_REIN_PLATE  PT00075766
# 2720   STRUCTURE  PT00075768     JOINING_CRUSH_CAN ; Grande  PT00075766
# 2739   STRUCTURE  PT00090141        CORNER RADAR BRACKET-LH  PT00024055
# 2740   STRUCTURE  PT00090140        CORNER RADAR BRACKET-RH  PT00024055
# ...          ...         ...                            ...         ...
# 69315    BATTERY  PT00051311                 Motorboat Tail  PT00015975
# 69317    BATTERY  PT00051315             Sour Patch Gummies  PT00015983
# 69319    BATTERY  PT00051311                 Motorboat Tail  PT00015975
# 69321    BATTERY  PT00051315             Sour Patch Gummies  PT00015983
# 69323    BATTERY  PT00051311                 Motorboat Tail  PT00015975
#
#       Responsible Engineer Procurement Code Sub Component Code  \
# 2717         Pheobe Buffay              Buy        SupplierBuy
# 2718         Pheobe Buffay              Buy        SupplierBuy
# 2720         Pheobe Buffay          Phantom                NaN
# 2739         Pheobe Buffay              Buy        SupplierBuy
# 2740         Pheobe Buffay              Buy        SupplierBuy
# ...                    ...              ...                ...
# 69315      Dawn Bellwether              Buy        SupplierBuy
# 69317      Dawn Bellwether              Buy        SupplierBuy
# 69319      Dawn Bellwether              Buy        SupplierBuy
# 69321      Dawn Bellwether              Buy        SupplierBuy
# 69323      Dawn Bellwether              Buy        SupplierBuy
#
#                                            Variant
# 2717
# 2718
# 2720
# 2739
# 2740
# ...                                            ...
# 69315  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69317  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69319  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69321  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
# 69323  QRV: Battery{LMAO 5 Module,LMAO 190 Module}
#
# [1754 rows x 11 columns]

# %%
# of the 3299 rows that fit this category, 2450 are correct

import pandas as pd
import matplotlib.pyplot as plt


# Group by 'systems' and 'subsystem' and count
grouped = right_rows_df.groupby(['System', 'Subsystem']).size().unstack(fill_value=0)

# Plot stacked bar chart
grouped.plot(kind='bar', stacked=True, figsize=(10, 6))

plt.xlabel('Systems')
plt.ylabel('Count')
plt.title('Stacked Column Chart')
plt.legend(title='Subsystem', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
import pandas as pd

# Sample DataFrame

# Print counts of unique values in 'systems' column
wrong = wrong_rows_df['Subsystem'].value_counts().sort_index()

print(wrong)
# Out:
# BATTERY                         252
# BRAKES                            4
# CLOSURES                         71
# DOORS                             4
# EXTERIOR                         42
# HARDWARE - LOW VOLTAGE           45
# POWER DISTRIBUTION SUBSYSTEM      1
# PROPULSION - FRT                  8
# SEATS                           106
# STEERING                          1
# STRUCTURE                       367
# SUSPENSION                        2
# TRIM                             28
# Name: Subsystem, dtype: int64

# %%
import pandas as pd

# Sample DataFrame

# Print counts of unique values in 'systems' column
right = right_rows_df['Subsystem'].value_counts().sort_index()

print(right)
# Out:
# BATTERY                         324
# BRAKES                           26
# CLOSURES                        165
# COCKPIT                          15
# DOORS                            19
# EXTERIOR                         92
# HARDWARE - LOW VOLTAGE           47
# POWER DISTRIBUTION SUBSYSTEM      1
# SEATS                           461
# STEERING                         11
# STRUCTURE                       461
# SUSPENSION                       21
# TRIM                             99
# VEHICLE ACCESS                   12
# Name: Subsystem, dtype: int64

# %%
combined_series = wrong.add(right, fill_value=0).astype(int)

division_series = right.divide(combined_series, fill_value=0)

# Replace NaN values with 0
division_series = division_series.fillna(0)

# Print the division result
print(division_series)
# Out:
# BATTERY                         0.562500
# BRAKES                          0.866667
# CLOSURES                        0.699153
# COCKPIT                         1.000000
# DOORS                           0.826087
# EXTERIOR                        0.686567
# HARDWARE - LOW VOLTAGE          0.510870
# POWER DISTRIBUTION SUBSYSTEM    0.500000
# PROPULSION - FRT                0.000000
# SEATS                           0.813051
# STEERING                        0.916667
# STRUCTURE                       0.556763
# SUSPENSION                      0.913043
# TRIM                            0.779528
# VEHICLE ACCESS                  1.000000
# Name: Subsystem, dtype: float64

# %%
sorted_series = division_series.sort_values(ascending=False)

# Print the sorted Series
print(sorted_series)
# Out:
# COCKPIT                         1.000000
# VEHICLE ACCESS                  1.000000
# STEERING                        0.916667
# SUSPENSION                      0.913043
# BRAKES                          0.866667
# DOORS                           0.826087
# SEATS                           0.813051
# TRIM                            0.779528
# CLOSURES                        0.699153
# EXTERIOR                        0.686567
# BATTERY                         0.562500
# STRUCTURE                       0.556763
# HARDWARE - LOW VOLTAGE          0.510870
# POWER DISTRIBUTION SUBSYSTEM    0.500000
# PROPULSION - FRT                0.000000
# Name: Subsystem, dtype: float64

# %%
import matplotlib.pyplot as plt

# Sort the division result by values in descending order
sorted_series = division_series.sort_values(ascending=False)

# Create the bar plot
plt.figure(figsize=(12, 8))
sorted_series.plot(kind='bar', color='skyblue')
plt.xlabel('Subsystem')
plt.ylabel('Division Result')
plt.title('Procurement Code Health By Subsystem')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
words_to_search = ['Tall', 'tall']
column_to_search = 'Variant'

# Create a pattern to search for multiple words
pattern = '|'.join(words_to_search)

# Count occurrences of the words in the "Description" column
count = wrong_rows_df[column_to_search].str.contains(pattern, case=False, na=False).sum()


print(count)

words_to_search = ['Grande', 'grande']
column_to_search = 'Variant'

# Create a pattern to search for multiple words
pattern = '|'.join(words_to_search)

# Count occurrences of the words in the "Description" column
count = wrong_rows_df[column_to_search].str.contains(pattern, case=False, na=False).sum()


print(count)

words_to_search = ['Venti', 'venti']
column_to_search = 'Variant'

# Create a pattern to search for multiple words
pattern = '|'.join(words_to_search)

# Count occurrences of the words in the "Description" column
count = wrong_rows_df[column_to_search].str.contains(pattern, case=False, na=False).sum()


print(count)
# Out:
# 232
# 326
# 258

# %%
words_to_search = ['Tall', 'tall']
column_to_search = 'Variant'

# Create a pattern to search for multiple words
pattern = '|'.join(words_to_search)

# Count occurrences of the words in the "Description" column
count = filtered_df[column_to_search].str.contains(pattern, case=False, na=False).sum()


print(count)

words_to_search = ['Grande', 'grande']
column_to_search = 'Variant'

# Create a pattern to search for multiple words
pattern = '|'.join(words_to_search)

# Count occurrences of the words in the "Description" column
count = filtered_df[column_to_search].str.contains(pattern, case=False, na=False).sum()


print(count)

words_to_search = ['Venti', 'venti']
column_to_search = 'Variant'

# Create a pattern to search for multiple words
pattern = '|'.join(words_to_search)

# Count occurrences of the words in the "Description" column
count = filtered_df[column_to_search].str.contains(pattern, case=False, na=False).sum()


print(count)
# Out:
# 797
# 1007
# 854

# %%
# of the 3299 rows that fit this category, 2450 are correct


# sort by level, insert into tree, 


# find if some rows don't have existing parents


import pandas as pd

# Sample DataFrame

# Print counts of unique values in 'systems' column
total = filtered_df['Level'].value_counts().sort_index()

import pandas as pd

# Sample DataFrame

# Print counts of unique values in 'systems' column
wrong = wrong_rows_df['Level'].value_counts().sort_index()

import pandas as pd

# Sample DataFrame

# Print counts of unique values in 'systems' column
right = right_rows_df['Level'].value_counts()

import pandas as pd

# Sample DataFrame

# Print counts of unique values in 'systems' column
wrong = wrong_rows_df['Level'].value_counts()

combined_series = wrong.add(right, fill_value=0).astype(int)

division_series = right.divide(combined_series, fill_value=0)

# Replace NaN values with 0
division_series = division_series.fillna(0)

# Print the division result

sorted_series = division_series

# Print the sorted Series

import matplotlib.pyplot as plt

# Sort the division result by values in descending order
sorted_series = division_series

# Create the bar plot
plt.figure(figsize=(12, 8))
sorted_series.plot(kind='bar', color='skyblue')
plt.xlabel('Level')
plt.ylabel('Division Result')
plt.title('Procurement Code Health By Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
